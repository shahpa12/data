# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tweet = pd.read_csv("vaccination_tweets.csv")

# %%
tweet["text"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       Same folks said daikon paste could treat a cyt...
# 1       While the world has been on the wrong side of ...
# 2       #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3       Facts are immutable, Senator, even when you're...
# 4       Explain to me again why we need a vaccine @Bor...
#                               ...
# 2202    Got my #COVID19 vaccine 💉 early morning on Dec...
# 2203    Where is #tiffanydover ? Why no one has news f...
# 2204    BILL GATES &amp; WALTER WHITE ON - BREAKING GA...
# 2205    Words can’t express how grateful I am to all t...
# 2206    @DailyMailUK While I trust the #Pfizervaccine ...
# Name: text, Length: 2207, dtype: object>

# %%
tweet.nunique()
# Out:
# id                  2207
# user_name           1499
# user_location        778
# user_description    1423
# user_created        1500
# user_followers      1163
# user_friends        1045
# user_favourites     1428
# user_verified          2
# date                2205
# text                2207
# hashtags            1065
# source                24
# retweets              41
# favorites            111
# is_retweet             1
# dtype: int64

# %%
tweet['source'].unique
# Out:
# <bound method Series.unique of 0       Twitter for Android
# 1           Twitter Web App
# 2       Twitter for Android
# 3           Twitter Web App
# 4        Twitter for iPhone
#                ...
# 2202     Twitter for iPhone
# 2203    Twitter for Android
# 2204        Twitter Web App
# 2205     Twitter for iPhone
# 2206     Twitter for iPhone
# Name: source, Length: 2207, dtype: object>

# %%
tweet[tweet.user_location == 'San Francisco, CA']
# Out:
#                        id                user_name      user_location  \
# 1     1338158543359250433              Albert Fong  San Francisco, CA
# 295   1337879732663160834            World Affairs  San Francisco, CA
# 304   1337859839205109760                Alex Witt  San Francisco, CA
# 482   1339387052027125760                 SFVaughn  San Francisco, CA
# 1075  1340480662784995329  Paul Hsiao, PharmD, RPh  San Francisco, CA
# 1261  1341810413860577280  Paul Hsiao, PharmD, RPh  San Francisco, CA
# 1264  1341803764450127873  Paul Hsiao, PharmD, RPh  San Francisco, CA
# 1552  1341079706582433792              Simon Bloch  San Francisco, CA
#
#                                        user_description         user_created  \
# 1     Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 295        Insight, Action, Purpose.  RT ≠ endorsement.  2009-06-09 18:35:51
# 304   Head of Finance at cLabs, shaping @CeloOrg\nEn...  2009-04-06 03:03:52
# ...

# %%
tweet[tweet.user_location == 'San Francisco, CA'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 1 to 1552
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                8 non-null      int64
#  1   user_name         8 non-null      object
#  2   user_location     8 non-null      object
#  3   user_description  8 non-null      object
#  4   user_created      8 non-null      object
#  5   user_followers    8 non-null      int64
#  6   user_friends      8 non-null      int64
#  7   user_favourites   8 non-null      int64
#  8   user_verified     8 non-null      bool
#  9   date              8 non-null      object
#  10  text              8 non-null      object
#  11  hashtags          4 non-null      object
#  12  source            8 non-null      object
#  13  retweets          8 non-null      int64
#  14  favorites         8 non-null      int64
#  15  is_retweet        8 non-null      bool
# ...

# %%
tweet.head(2)
# Out:
#                     id    user_name              user_location  \
# 0  1340539111971516416   Rachel Roh  La Crescenta-Montrose, CA
# 1  1338158543359250433  Albert Fong          San Francisco, CA
#
#                                     user_description         user_created  \
# 0  Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
#
#                   date                                               text  \
# 0  2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# 1  2020-12-13 16:27:13  While the world has been on the wrong side of ...
#
#              hashtags               source  retweets  favorites  is_retweet
# ...

# %%
tweet[tweet['text'].str.contains('vaccine')]

tweet[tweet['text'].str.contains('vaccine')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 2 to 2206
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1108 non-null   int64
#  1   user_name         1108 non-null   object
#  2   user_location     843 non-null    object
#  3   user_description  1056 non-null   object
#  4   user_created      1108 non-null   object
#  5   user_followers    1108 non-null   int64
#  6   user_friends      1108 non-null   int64
#  7   user_favourites   1108 non-null   int64
#  8   user_verified     1108 non-null   bool
#  9   date              1108 non-null   object
#  10  text              1108 non-null   object
#  11  hashtags          875 non-null    object
#  12  source            1108 non-null   object
#  13  retweets          1108 non-null   int64
#  14  favorites         1108 non-null   int64
#  15  is_retweet        1108 non-null   bool
# ...

# %%
tweet[tweet.user_followers>=405]
# Out:
#                        id            user_name                user_location  \
# 0     1340539111971516416           Rachel Roh    La Crescenta-Montrose, CA
# 1     1338158543359250433          Albert Fong            San Francisco, CA
# 3     1337855739918835717        Charles Adler       Vancouver, BC - Canada
# 6     1337851215875608579    Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7     1337850832256176136  Dr.Krutika Kuppalli                          NaN
# ...                   ...                  ...                          ...
# 2195  1343063948371742721   Anuja Chandramouli                          NaN
# 2196  1343046584091639809    New Straits Times                     Malaysia
# 2197  1343044441909547008     Chris Lancashire                          NaN
# 2199  1343021281042714624            Gulf News         United Arab Emirates
# 2200  1343014950000709632    New Straits Times                     Malaysia
#
# ...
